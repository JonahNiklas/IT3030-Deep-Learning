# %%
from Doodler import load_doodle_cases, show_doodle_cases

data, target, labels, img_dim, flat = load_doodle_cases("doodle_cases.pkl")
show_doodle_cases((data[:10], target[:10], labels[:10], img_dim, flat))
